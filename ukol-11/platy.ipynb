# %%
import pandas

# %%
platy = pandas.read_csv("platy_2021_02.csv", index_col='cislo_zamestnance')

# %%
platy.hist(bins=[30000.0, 40000.0, 50000.0, 60000.0])
# Out:
# array([[<Axes: title={'center': 'plat'}>]], dtype=object)
